# %%
import pdfplumber as pp

with pp.open('/Users/hiro0x/Documents/alphaprime/misc/screenshots/18- Summary.pdf') as book:
    for page_no, page in enumerate(book.pages, start=1):
        print(f'{page_no = }')
        data = page.extract_text()
        print(data.strip())
        print('-'*45)
# Out:
# page_no = 1
# The Ultimate Docker Course  1
# The Linux Command Line
# Managing packages
# apt update
# apt list
# apt install nano
# apt remove nano
# Navigating the ﬁle system
# pwd          # to print the working directory
# ls     # to list the files and directories
# ls -l        # to print a long list
# cd /    # to go to the root directory
# cd bin    # to go to the bin directory
# cd ..     # to go one level up
# cd ~    # to go to the home directory
# Manipulating ﬁles and directories
# mkdir test              # to create the test directory
# mv test docker     # to rename a directory
# touch file.txt      # to create file.txt
# mv file.txt hello.txt   # to rename a file
# rm hello.txt        # to remove a file
# rm -r docker      # to recursively remove a directory
# codewithmosh.com
# ---------------------------------------------
# page_no = 2
# The Ultimate Docker Course  2
# Editing and viewing ﬁles
# nano file.txt        # to edit file.txt
# ...
